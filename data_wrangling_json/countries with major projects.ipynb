# %% [markdown]
# # Import json, pandas

# %%
import json
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize

# %% [markdown]
# # load data from file and convert to pandas dataframe

# %%
# load the json data into python variable

with open('data/world_bank_projects.json') as f:
    data = json.load(f)
    
# normalize data to get theme details from json nested key
df = json_normalize(data, 'mjtheme_namecode', ['countryshortname', 'project_name'])

# fill blank theme names with Miscellaneous
df['name'] = df['name'].replace(r'^\s*$', np.nan, regex=True).fillna('Miscellaneous')

df
# Out:
#      code                                          name  \
# 0       8                             Human development
# 1      11                                 Miscellaneous
# 2       1                           Economic management
# 3       6         Social protection and risk management
# 4       5                         Trade and integration
# 5       2                      Public sector governance
# 6      11  Environment and natural resources management
# 7       6         Social protection and risk management
# 8       7                   Social dev/gender/inclusion
# 9       7                   Social dev/gender/inclusion
# 10      5                         Trade and integration
# 11      4      Financial and private sector development
# 12      6         Social protection and risk management
# 13      6                                 Miscellaneous
# 14      2                      Public sector governance
# 15      4      Financial and private sector development
# ...

# %% [markdown]
# # get countries with major project with groupby and nlargest methods

# %%
# using group by, find the number of projects done in each country
df1 = df.groupby(['countryshortname']).size().reset_index(name='project_counts')

#print the top 10 countries with major projects
df1.nlargest(10, 'project_counts')
# Out:
#        countryshortname  project_counts
# 45            Indonesia              56
# 44                India              51
# 112             Vietnam              43
# 8            Bangladesh              41
# 14               Brazil              41
# 23                China              40
# 1                Africa              39
# 115  Yemen, Republic of              34
# 69              Morocco              32
# 70           Mozambique              31

# %% [markdown]
# # Major project themes

# %%
# using group by, find the theme count
df2 = df.groupby(['code', 'name']).size().reset_index(name='theme_counts')


#print the top 10 themes among projects
df2.nlargest(10, 'theme_counts')
# Out:
#    code                                          name  theme_counts
# 4    11  Environment and natural resources management           223
# 3    10                             Rural development           202
# 18    8                             Human development           197
# 7     2                      Public sector governance           184
# 15    6         Social protection and risk management           158
# 10    4      Financial and private sector development           130
# 17    7                   Social dev/gender/inclusion           119
# 13    5                         Trade and integration            72
# 21    9                             Urban development            47
# 0     1                           Economic management            33
